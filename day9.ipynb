# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# using ‘supermarket_sales.csv’ file do the following operations and give required answer by using proper programming process.
# 1). Load the dataset into a pandas DataFrame and read first 8 rows.
# 2). Check for missing values and fill it by mean values of that particular column if any.
# 3). Find the number of orders which have ‘Quantity’ less than 3 and which have (either ‘Rating’ greater than 8.5 or ‘Total’ greater than 600).
# 4). Find the sum of ‘Total’ purchasing price spent by Member and Normal 'Customer type'.
# 5). Find the percentage of total of ‘gross income’ based on the different ‘Payment’ methods used by customers. (Ewallet, Cash and Credit card)
# 6). Analyze the purchasing behavior of male and female customers using ‘Gender’ column. Find their average purchase prices using ‘Total’ 
# column.
# 7). Create a scatter plot that shows the relationship between total amount spent and rating. (keep ‘+’ marker, with marker size 100 and green 
# color).
# 8). Create a box plot that shows the distribution of ‘Rating’ and ‘Quantity’. And comment about outliers in both columns.
# 9). Visualize with parallel co-ordinates for ‘Unit price’, ‘Total’, ’cogs’ columns’ data with respect to ‘Product line’.

# %%
super=pd.read_csv('supermarket_sales.csv')
super
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
super.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       4
# gross margin percentage    0
# gross income               0
# Rating                     5
# dtype: int64

# %%
super['cogs']=super['cogs'].fillna(super['cogs'].mean())
super['Rating']=super['Rating'].fillna(super['Rating'].mean())

# %%
super.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
# 3). Find the number of orders which have ‘Quantity’ less than 3 and which have 
# (either ‘Rating’ greater than 8.5 or ‘Total’ greater than 600).
super.loc[(super['Quantity']<3)&((super['Rating']>8.5)|(super['Total']>600))]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 188  400-60-7251      A     Yangon        Normal    Male
# 225  746-68-6593      C  Naypyitaw        Member  Female
# 256  366-93-0948      A     Yangon        Member    Male
# 271  687-15-1097      C  Naypyitaw        Member  Female
# 311  181-94-6432      C  Naypyitaw        Member    Male
# 402  236-86-3015      C  Naypyitaw        Member    Male
# 417  186-09-3669      C  Naypyitaw        Member  Female
# 443  192-98-7397      C  Naypyitaw        Normal    Male
# 445  390-80-5128      B   Mandalay        Member  Female
# 449  449-27-2918      B   Mandalay        Member  Female
# 498  401-18-8016      B   Mandalay        Member  Female
# 501  573-98-8548      C  Naypyitaw        Member  Female
# 502  620-02-2046      C  Naypyitaw        Normal    Male
# 504  511-54-3087      B   Mandalay        Normal    Male
# 518  220-28-1851      A     Yangon        Normal    Male
# ...

# %%
# 4). Find the sum of ‘Total’ purchasing price spent by Member and Normal 'Customer type'.

super1=super.groupby('Customer type')['Total'].sum()
super1
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
# 5). Find the percentage of total of ‘gross income’ based on the different ‘Payment’ methods used by customers. (Ewallet, Cash and Credit card)
incomes=super.groupby('Payment')['gross income'].sum()/super['gross income'].sum()*100
incomes
# Out:
# Payment
# Cash           34.742453
# Credit card    31.200448
# Ewallet        34.057099
# Name: gross income, dtype: float64

# %%
super['Customer type'].unique()

# %%
analyze=super.groupby("Gender")['Total'].mean()
print(analyze)
# Out:
# Gender
# Female    335.095659
# Male      310.789226
# Name: Total, dtype: float64

# %%
super.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
# 7). Create a scatter plot that shows the relationship between total amount spent and rating. (keep ‘+’ marker, with marker size
# 100 and green 
fig,ax=plt.subplots()
plt.scatter(super['Total'],super['Rating'],s=100,marker='+',color=['green'])
plt.show()

# %%
# 8). Create a box plot that shows the distribution of ‘Rating’ and ‘Quantity’. And comment about outliers in both columns.
plt.boxplot([super['Quantity'],super['Rating']])
plt.show()
# there are no any outliers

# %%
# 9). Visualize with parallel co-ordinates for ‘Unit price’, ‘Total’, ’cogs’ columns’ data with respect to ‘Product line’.
from pandas.plotting import parallel_coordinates
pll=parallel_coordinates(super,'Product line',cols=['Unit price','Total','cogs'],color=['red','blue','green','yellow','orange'])
plt.show()

# %%
# To upload the ‘diabetes_unclean.csv’ to your working folder
# First import the following libraries
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# 1.Make a data frame with the variable name df 
# 2.To display the specific staƟsƟcs or measures that are relevant for object-type columns
# 3.To display the specific staƟsƟcs or measures that are relevant for numerical-type columns
# 4.How many rows and columns are in a given dataset
# 5.To check the missing values
# 6.To replace the missing values in the column "HbA1c" with their mean value
# 7.Dropping the missing values of other columns
# 8.Display the correlaƟon between variables
# 9. Checking the outliers in the dataset for the following parameters: 'AGE', 'Urea', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI' using box plot 
# with labels and title
# 10.Visualized the "Urea", "HbA1c", "TG" and "BMI" parameters for different ages using parallel_coordinates with labels and Ɵtle
# 11.Remove the rows whose gender column has an “f” value and give the frequency count of the “F” and “M” values in different CLASS values
# 12.Remove the outliers in the "HbA1c" columns and print the shape of the data frame
# Note: all task output with specific question numbers and follow the sequence 
# Example: print(“Ans-1”)

# %%
df=pd.read_csv('diabetes_unclean.csv')
df
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 1      0.6  23.0     N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1009 non-null   int64
#  1   No_Pation  1009 non-null   int64
#  2   Gender     1009 non-null   object
#  3   AGE        1008 non-null   float64
#  4   Urea       1008 non-null   float64
#  5   Cr         1007 non-null   float64
#  6   HbA1c      1006 non-null   float64
#  7   Chol       1007 non-null   float64
#  8   TG         1007 non-null   float64
#  9   HDL        1008 non-null   float64
#  10  LDL        1007 non-null   float64
#  11  VLDL       1008 non-null   float64
#  12  BMI        1009 non-null   float64
#  13  CLASS      1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB

# %%
df.describe(include='object')
# Out:
#        Gender CLASS
# count    1009  1009
# unique      3     5
# top         M     Y
# freq      570   840

# %%
df.describe(include='number')
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1009.000000  1.009000e+03  1008.000000  1008.000000  1007.000000
# mean    339.161546  2.717448e+05    53.620040     5.131094    68.973188
# std     239.738169  3.365681e+06     8.740975     2.931136    59.813297
# min       1.000000  1.230000e+02    25.000000     0.500000     6.000000
# 25%     127.000000  2.406500e+04    51.000000     3.700000    48.000000
# 50%     296.000000  3.439900e+04    55.000000     4.600000    60.000000
# 75%     548.000000  4.539000e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1006.000000  1007.000000  1007.000000  1008.000000  1007.000000
# mean      8.284155     4.863873     2.348769     1.204216     2.610119
# std       2.533576     1.297326     1.397487     0.658158     1.116095
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1009 non-null   int64
#  1   No_Pation  1009 non-null   int64
#  2   Gender     1009 non-null   object
#  3   AGE        1008 non-null   float64
#  4   Urea       1008 non-null   float64
#  5   Cr         1007 non-null   float64
#  6   HbA1c      1006 non-null   float64
#  7   Chol       1007 non-null   float64
#  8   TG         1007 non-null   float64
#  9   HDL        1008 non-null   float64
#  10  LDL        1007 non-null   float64
#  11  VLDL       1008 non-null   float64
#  12  BMI        1009 non-null   float64
#  13  CLASS      1009 non-null   object
# dtypes: float64(10), int64(2), object(2)
# memory usage: 110.5+ KB

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
df['HbA1c']=df['HbA1c'].fillna(df['HbA1c'].mean())

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        0
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.corr()
# Out:
#                  ID  No_Pation       AGE      Urea        Cr     HbA1c  \
# ID         1.000000   0.064599 -0.072687 -0.094891 -0.100046 -0.009037
# No_Pation  0.064599   1.000000 -0.088870 -0.019061  0.000973 -0.032350
# AGE       -0.072687  -0.088870  1.000000  0.108613  0.056940  0.384675
# Urea      -0.094891  -0.019061  0.108613  1.000000  0.624810 -0.023307
# Cr        -0.100046   0.000973  0.056940  0.624810  1.000000 -0.037735
# HbA1c     -0.009037  -0.032350  0.384675 -0.023307 -0.037735  1.000000
# Chol       0.045414  -0.030288  0.038966  0.001286 -0.007636  0.177676
# TG        -0.054110  -0.039859  0.149274  0.040939  0.056031  0.214030
# HDL        0.025226  -0.013554 -0.021029 -0.037843 -0.023578  0.030455
# LDL       -0.065718  -0.003520  0.011496 -0.006673  0.040981  0.011536
# VLDL       0.145700   0.113635 -0.090796 -0.011573  0.010328  0.072641
# BMI        0.047270   0.017738  0.381176  0.045753  0.054847  0.413130
#
# ...

# %%
# 9. Checking the outliers in the dataset for the following parameters: 'AGE', 'Urea'
# , 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI' using box plot 
# with labels and title
plt.boxplot([df['AGE'],df['Urea'],df['HbA1c'],df['Chol'],df['TG'],df['HDL'],df['LDL'],df['VLDL'],df['BMI']])
plt.show()

# %%
# 10.Visualized the "Urea", "HbA1c", "TG" and "BMI" parameters for different ages using parallel_coordinates with labels and Ɵtle
from pandas.plotting import parallel_coordinates
pll=parallel_coordinates(df,'AGE',cols=['Urea','HbA1c','TG','BMI'],color=['red','blue','green','yellow','orange'])
plt.show()

# %%
# 11.Remove the rows whose gender column has an “f” value and give the frequency count of the “F” and “M” values in different CLASS values
df.head(10)
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
# 5  634      34224      F  45.0   2.3  24.0    4.0   2.9  1.0  1.0  1.5   0.4
# 6  721      34225      F  50.0   2.0  50.0    4.0   3.6  1.3  0.9  2.1   0.6
# 7  421      34227      M  48.0   4.7  47.0    4.0   2.9  0.8  0.9  1.6   0.4
# 8  670      34229      M  43.0   2.6  67.0    4.0   3.8  0.9  2.4  3.7   1.0
# 9  759      34230      F  32.0   3.6  28.0    4.0   3.8  2.0  2.4  3.8   1.0
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
# 5  21.0     N
# ...

# %%
df=df[df['Gender']!='f']

# %%
df
# Out:
#        ID  No_Pation Gender   AGE  Urea     Cr     HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7   46.0  4.900000   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5   62.0  4.900000   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7   46.0  4.900000   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7   46.0  4.900000   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1   46.0  4.900000   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...    ...       ...   ...  ...  ...  ...
# 1000  185     454316      M  64.0   8.8  106.0  8.500000   5.9  2.1  1.2  4.0
# 1002  188     454316      F  75.0  10.3  113.0  8.600000   4.2  1.6  0.9  2.6
# 1003  189     454316      M  58.0   4.0   55.0  7.900000   4.9  2.0  1.2  1.4
# 1005  192     454316      M  55.0   4.8   88.0  8.284155   5.7  4.0  0.9  3.3
# 1007  194     454316      F  57.0   4.1   70.0  9.300000   5.3  3.3  1.0  1.4
#
#       VLDL   BMI CLASS
# ...

# %%
pd.crosstab(df['CLASS'],df['Gender'])
# Out:
# Gender    F    M
# CLASS
# N        64   38
# N         0    1
# P        17   36
# Y       349  482
# Y         2    6

# %%
pd.replace({''})
